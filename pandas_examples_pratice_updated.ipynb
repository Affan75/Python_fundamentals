# %% [markdown]
# <a href="https://colab.research.google.com/github/Affan75/Python_fundamentals/blob/main/pandas_examples_pratice_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Pandas Concepts***

# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#to view first 5 records in our dataframe
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
#bottom 5 record in our dataset
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.shape
# Out:
# (78, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
import warnings
warnings.filterwarnings('ignore')
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427907

# %%
df['salary'].std()
# Out:
# 28293.66102226417

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df[['salary','service', 'phd']].mean()
# Out:
# salary     108023.782051
# service        15.051282
# phd            19.705128
# dtype: float64

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50, 0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# 5        Prof          A   20       20
# 6   AssocProf          A   20       17
# 7        Prof          A   18       18
# 8        Prof          A   29       19
# 9        Prof          A   51       51
# 10       Prof          B   39       33
# 11       Prof          B   23       23
# 12   AsstProf          B    1        0
# 13       Prof          B   35       33
# 14       Prof          B   25       19
# 15       Prof          B   17        3
# 16   AsstProf          B    8        3
# 17   AsstProf          B    4        0
# 18       Prof          A   19        7
# 19       Prof          A   29       27
# 20   AsstProf          B    4        4
# 21       Prof          A   33       30
# 22   AsstProf          A    4        2
# ...

# %%
df.iloc[0:50, [0,1,3,4]]
# Out:
#          rank discipline  service     sex
# 0        Prof          B       49    Male
# 1        Prof          A        6    Male
# 2        Prof          A       20    Male
# 3        Prof          A       31    Male
# 4        Prof          B       18    Male
# 5        Prof          A       20    Male
# 6   AssocProf          A       17    Male
# 7        Prof          A       18    Male
# 8        Prof          A       19    Male
# 9        Prof          A       51    Male
# 10       Prof          B       33    Male
# 11       Prof          B       23    Male
# 12   AsstProf          B        0    Male
# 13       Prof          B       33    Male
# 14       Prof          B       19    Male
# 15       Prof          B        3    Male
# 16   AsstProf          B        3    Male
# 17   AsstProf          B        0    Male
# 18       Prof          A        7    Male
# 19       Prof          A       27    Male
# 20   AsstProf          B        4    Male
# ...

# %%
df.loc[0,'salary']
# Out:
# 186960

# %%
df1 = pd.read_csv('Salaries.csv', nrows =1)

# %%
df1
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %% [markdown]
# # ***Visualizations Concepts***

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df1 =pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
plt.title('Histogram of SAT')
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df1['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
sn.histplot(df1['Accept'])
plt.show()

# %%
sn.histplot(df1['SAT'])
plt.show()

# %%
plt.plot(df1['SAT'], df1['Accept'], 'rs')
plt.title('Scatterplot between SAT vs Accept')
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.show()

# %%
sn.scatterplot(x='SAT',y='Accept',data=df1)
# Out:
# <Axes: xlabel='SAT', ylabel='Accept'>

# %%
import warnings
warnings.filterwarnings('ignore')
sn.distplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
sn.distplot(df1['Top10'])
# Out:
# <Axes: xlabel='Top10', ylabel='Density'>

# %%
sn.pairplot(df1)

# %%
sn.pairplot(df1.iloc[:,1:4])

# %%
plt.boxplot(df1['SAT'])
plt.show()

# %%
plt.boxplot(df1['SAT'], vert = False)
plt.show()

# %%
df1.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df.groupby('rank')[['salary','phd']].mean()
# Out:
#                   salary        phd
# rank
# AssocProf   91786.230769  15.076923
# AsstProf    81362.789474   5.052632
# Prof       123624.804348  27.065217

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['Accept'])
# Out:
# (array([4., 5., 4., 5., 1., 2., 1., 2., 0., 1.]),
#  array([14. , 21.6, 29.2, 36.8, 44.4, 52. , 59.6, 67.2, 74.8, 82.4, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['Accept'])
plt.show()

# %%
plt.hist(df1['Accept'])
plt.xlabel('Accept')
plt.ylabel('Count')
plt.title('Histogram of Accept column')
plt.show()

# %%
sns.histplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Count'>

# %%
plt.plot(df1['Accept'],df1['SAT'],'bo')

# %%
plt.plot(df1['Accept'],df1['SAT'],'bo')

# %%
plt.plot(df1['Accept'],df1['SAT'],'rs')

# %%
plt.plot(df1['Accept'],df1['SAT'],'r+')

# %%
plt.plot(df1['Accept'],df1['SAT'],'rs')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatterplot between Accept & SAT')
# Out:
# Text(0.5, 1.0, 'Scatterplot between Accept & SAT')

# %%
sns.distplot(df1['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
sns.distplot(df1['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1.iloc[:,1:4])

# %%
plt.boxplot(df1['Accept'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bdcaf4d53f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bdcaf4d5930>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bdcaf4d5150>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bdcaf4d5e70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bdcaf4d6110>],
#  'means': []}

# %%
plt.boxplot(df1['Accept'],vert=False)
plt.show()

# %%
help(plt.boxplot)
# Out:
# Help on function boxplot in module matplotlib.pyplot:
#
# boxplot(x, notch=None, sym=None, vert=None, whis=None, positions=None, widths=None, patch_artist=None, bootstrap=None, usermedians=None, conf_intervals=None, meanline=None, showmeans=None, showcaps=None, showbox=None, showfliers=None, boxprops=None, labels=None, flierprops=None, medianprops=None, meanprops=None, capprops=None, whiskerprops=None, manage_ticks=True, autorange=False, zorder=None, capwidths=None, *, data=None)
#     Draw a box and whisker plot.
#
#     The box extends from the first quartile (Q1) to the third
#     quartile (Q3) of the data, with a line at the median.  The
#     whiskers extend from the box by 1.5x the inter-quartile range
#     (IQR).  Flier points are those past the end of the whiskers.
#     See https://en.wikipedia.org/wiki/Box_plot for reference.
#
#     .. code-block:: none
#
#               Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                            |-----:-----|
# ...

# %%
import numpy as np

# %%
a =np.array([1,2,3,4])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.size
# Out:
# 4

# %%
a.shape
# Out:
# (4,)

# %%
a.max()
# Out:
# 4

# %%
a.min()
# Out:
# 1

# %%
a.sum()
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
b = np.array([(1,2,3,4),(4,5,6,7)])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.size
# Out:
# 8

# %%
b.shape
# Out:
# (2, 4)

# %%
print(b)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
c=b.reshape(4,2)

# %%
c
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
b.max()
# Out:
# 7

# %%
b[0]
# Out:
# array([1, 2, 3, 4])

# %%
b[0][1]
# Out:
# 2

# %%
b.sum(axis=0)
# Out:
# array([ 5,  7,  9, 11])

# %%
b.sum(axis=1)
# Out:
# array([10, 22])
